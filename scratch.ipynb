# %%
import matplotlib.pyplot as plt

# %%
latency = [204570624, 53575680, 15826944, 6389760]
E1_CANDIDATES = [1, 4, 16, 64] 

plt.plot(E1_CANDIDATES, latency)
plt.show()

# %%
energy = [1.870e+15, 8.872e+14, 7.192e+14, 6.760e+14]
# gb_size = [65536*4096//16, 32768 * 2048 // 16, 16384 * 1024 // 16]
capacity = [33.5, 8.4, 2.1, 0.52]

plt.plot(capacity, energy, marker="o", markersize=3)
plt.xticks(capacity)
plt.xlabel("Global Buffer (MB)")
plt.ylabel("Energy")
plt.grid()
plt.show()
